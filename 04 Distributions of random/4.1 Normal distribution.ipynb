# %% [markdown]
# ![normald.png](attachment:normald.png)

# %% [markdown]
# ### Normal distribution model

# %% [markdown]
# ![normal.png](attachment:normal.png)

# %% [markdown]
# ### Standard Normal Distribution
#
# \begin{align*}
#     \mu &= 0 \\
#     \sigma & = 1
# \end{align*}

# %% [markdown]
# ### Standardizing with Z-scores
#
# \begin{align*}
#     z &= \frac{x - \mu}{\sigma}
# \end{align*}

# %% [markdown]
# ### Finding tail areas

# %% [markdown]
# ![normal2.png](attachment:normal2.png)

# %% [markdown]
# ### Normal probability examples

# %% [markdown]
# ![normal3.png](attachment:normal3.png)

# %% [markdown]
# ### 68-95-99.7 rule

# %% [markdown]
# ![ci.png](attachment:ci.png)
