# %% [markdown]
# ![negative_binomial.png](attachment:negative_binomial.png)

# %% [markdown]
# ### Finding kth success on nth trial
#
# ${n-1 \choose k-1} p^k (1-p)^{n-k} = \frac{(n-1)!}{(k-1)!(n-k)!} p^k (1-p)^{n-k}$
