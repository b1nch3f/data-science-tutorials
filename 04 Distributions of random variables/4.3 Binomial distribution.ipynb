# %% [markdown]
# ![binomial.png](attachment:binomial.png)

# %% [markdown]
# ### Finding k successes in n trials
# ${n \choose k} p^k (1-p)^{n-k} = \frac{n!}{k!(n-k)!} p^k (1-p)^{n-k}$

# %% [markdown]
# #### Expected value
#
# $\mu = np$
#
# #### Variance
#
# $\sigma^2 = np(1-p)$
#
# #### Standard deviation
#
# $\sigma = \sqrt{np(1-p)}$
